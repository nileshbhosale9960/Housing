# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_excel("housing (2) (1).xlsx")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#types of data
#longitude	latitude-continuous
#housing_median_age-continuous
#total_rooms-continuous-discrete
#total_bedrooms-discrete
#population-discrete
#households-discrete
#median_income-continuous
#median_house_value-continuous
#ocean_proximity-nominal

# %%
#1)What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.
df['median_income'].mean()
# Out:
# 3.8706710029069766

# %%
plt.figure(figsize=(10,10))
sns.histplot(df['median_income'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(df['median_income'])
plt.show()

# %%
#conclusion- According to the density plot we can say that the distribution is right skewed
#means means most of the data of meadian_income present at left side

# %%
#2)Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.
plt.hist(df["housing_median_age"],color='k')
plt.title("Housing_median_age Vs Frequencies ")
plt.xlabel("housing_median_age")
plt.ylabel("Frequencies")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(df['housing_median_age'])
plt.show()

# %%
df['housing_median_age'].describe()
# Out:
# count    20640.000000
# mean        28.639486
# std         12.585558
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %%
# conclusion above plot follow the general distribution having mean 28.63, std 12.58.
#it show oldest house is 52 year old new one 1 year before.

# %%
#3 Show with the help of visualization, how median_income and median_house_values are related?
plt.figure(figsize=(15,10))
sns.scatterplot(x="median_house_value",y="median_income",data=df)

# %%
# conclusion If you observe the scatter diagram it is increasing and somewhere linear as median income increases and median house value increases.
# max intensity of point mattaching of scattering found in intial point

# %%
4)# Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.
df[df.isnull().any(axis=1)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
# 5)Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.
data_set=df.dropna(subset=["total_bedrooms"])
data_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#6)Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.
df['longitude'].median()
# Out:
# -118.49

# %%
df['latitude'].median()
# Out:
# 34.26

# %%
df['housing_median_age'].median()
# Out:
# 29.0

# %%
df['total_rooms'].median()
# Out:
# 2127.0

# %%
df['total_bedrooms'].median()
# Out:
# 435.0

# %%
df['population'].median()
# Out:
# 1166.0

# %%
df['households'].median()
# Out:
# 409.0

# %%
df['median_income'].median()
# Out:
# 3.5347999999999997

# %%
df['median_house_value'].median()
# Out:
# 179700.0

# %%
#7. Plot latitude versus longitude and explain your observations.
plt.figure(figsize=(15,10))
sns.scatterplot(x='latitude',y='longitude',data=df)

# %%
# conclusion- latitude versus longitude observations show that relationship is collinear.
# as the value of latitude increasing value of longitude decreasing and viceversa

# %%
#8. Create a data set for which the ocean_proximity is ‘Near ocean
data_set=df.loc[df["ocean_proximity"]=="NEAR OCEAN"]
data_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                16.0       2739.0           480.0
# 1851     -124.30     41.80                19.0       2672.0           552.0
# 1852     -124.23     41.75                11.0       3159.0           616.0
# 1853     -124.21     41.77                17.0       3461.0           722.0
# 1854     -124.19     41.78                15.0       3140.0           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                16.0       1316.0           194.0
# 20381    -118.83     34.14                16.0       1956.0           312.0
# 20423    -119.00     34.08                17.0       1822.0           438.0
# 20424    -118.75     34.18                 4.0      16704.0          2704.0
# 20425    -118.75     34.17                18.0       6217.0           858.0
#
# ...

# %%
#9. Find the mean and median of the median income for the data set created in question 8
data_set['median_income'].mean()
# Out:
# 4.0057848006019565

# %%
data_set['median_income'].median()
# Out:
# 3.64705

# %%
#10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small.
#If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large
def match(a):
  if a<=10:
    return ("small")
  elif a>10 and a<1000:
    return ("medium")
  else:
    return ("large")
df['total_bedroom_size']=df['total_bedrooms'].map(match)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   total_bedroom_size
# 0             medium
# 1              large
# ...
